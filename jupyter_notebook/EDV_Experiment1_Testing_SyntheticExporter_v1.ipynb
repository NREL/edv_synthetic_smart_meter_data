# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# where is the stich controlling file, and how does it look like?

# %%
file_ctrl = "../spec/files/generation_script.csv"
df_ctrl = pd.read_csv(file_ctrl)
df_ctrl
# Out:
#       realization_name  Office_Cristina  UnivClass_Abby  PrimClass_Jaylin  \
# 0   basic_scenario_dir  Office_Cristina  UnivClass_Abby  PrimClass_Jaylin
# 1          building_id                1               1                 1
# 2     default_scenario         Baseline        Baseline          Baseline
# 3           start_date         1/1/2017        1/1/2017          1/1/2017
# 4             end_date       12/31/2017      12/31/2017        12/31/2017
# 5      scenario_name_1       "LED Only"   "All Package"        "LED Only"
# 6       active_after_1         3/1/2017        8/5/2017         3/25/2017
# 7      scenario_name_2    "All Package"      "LED Only"     "All Package"
# 8       active_after_2         7/9/2017       11/9/2017         3/28/2017
# 9      scenario_name_3              NaN             NaN               NaN
# 10      active_after_3              NaN             NaN               NaN
# 11     scenario_name_4              NaN             NaN               NaN
# 12      active_after_4              NaN             NaN               NaN
# 13     scenario_name_5              NaN             NaN               NaN
# 14      active_after_5              NaN             NaN               NaN
# 15     scenario_name_6              NaN             NaN               NaN
# 16      active_after_6              NaN             NaN               NaN
# 17     scenario_name_7              NaN             NaN               NaN
# 18      active_after_7              NaN             NaN               NaN
# 19     scenario_name_8              NaN             NaN               NaN
# 20      active_after_8              NaN             NaN               NaN
# 21     scenario_name_9              NaN             NaN               NaN
# 22      active_after_9              NaN             NaN               NaN
# 23    scenario_name_10              NaN             NaN               NaN
# 24     active_after_10              NaN             NaN               NaN
#
#     UnivDorm_Chester  UnivLab_Andre  Office_Caleb  PrimClass_Jean  \
# 0   UnivDorm_Chester  UnivLab_Andre  Office_Caleb  PrimClass_Jean
# 1                  1              1             1               1
# 2           LED Only       Baseline      Baseline        Baseline
# 3           1/1/2017       1/1/2017      1/1/2017        1/1/2017
# 4         12/31/2017     12/31/2017    12/31/2017      12/31/2017
# 5           Baseline     "LED Only"           NaN      "LED Only"
# 6         11/11/2017       1/2/2017           NaN        1/2/2017
# 7      "All Package"  "All Package"           NaN   "All Package"
# 8         12/12/2017       1/3/2017           NaN        1/3/2017
# 9                NaN     "LED Only"           NaN      "LED Only"
# 10               NaN       1/4/2017           NaN        1/4/2017
# 11               NaN  "All Package"           NaN             NaN
# 12               NaN       1/5/2017           NaN             NaN
# 13               NaN     "LED Only"           NaN             NaN
# 14               NaN       1/8/2017           NaN             NaN
# 15               NaN  "All Package"           NaN             NaN
# 16               NaN       2/1/2017           NaN             NaN
# 17               NaN     "LED Only"           NaN             NaN
# 18               NaN       3/1/2017           NaN             NaN
# 19               NaN  "All Package"           NaN             NaN
# 20               NaN       5/5/2017           NaN             NaN
# 21               NaN     "LED Only"           NaN             NaN
# 22               NaN       8/5/2017           NaN             NaN
# 23               NaN  "All Package"           NaN             NaN
# 24               NaN     10/10/2017           NaN             NaN
#
#     UnivClass_Alvin  UnivDorm_Cathalina  \
# 0   UnivClass_Alvin  UnivDorm_Cathalina
# 1                 1                   1
# 2          Baseline            Baseline
# 3          1/1/2017            1/1/2017
# 4        12/31/2017          12/31/2017
# 5        "LED Only"          "LED Only"
# 6          1/2/2017            1/2/2017
# 7     "All Package"       "All Package"
# 8          1/3/2017            1/3/2017
# 9        "LED Only"          "LED Only"
# 10         1/4/2017            1/4/2017
# 11    "All Package"       "All Package"
# 12         1/5/2017            1/5/2017
# 13       "LED Only"          "LED Only"
# 14         1/8/2017            1/8/2017
# 15              NaN       "All Package"
# 16              NaN            2/1/2017
# 17              NaN          "LED Only"
# 18              NaN            3/1/2017
# 19              NaN       "All Package"
# 20              NaN            5/5/2017
# 21              NaN                 NaN
# 22              NaN                 NaN
# 23              NaN                 NaN
# 24              NaN                 NaN
#
#                                    UnivLab_Allison
# 0                                  UnivLab_Allison
# 1                                                1
# 2                                         Baseline
# 3                                         1/1/2017
# 4                                       12/31/2017
# 5                                       "LED Only"
# 6                                         1/2/2017
# 7                                    "All Package"
# 8                                         1/3/2017
# 9                    "Cooling_System_SEER 14 Only"
# 10                                        1/4/2017
# 11  "Air_Seal_Infiltration_30%_More_Airtight Only"
# 12                                        1/5/2017
# 13         "Electric_Appliance_30%_Reduction Only"
# 14                                        1/8/2017
# 15                                   "All Package"
# 16                                        2/1/2017
# 17                                      "LED Only"
# 18                                        3/1/2017
# 19                                   "All Package"
# 20                                        5/5/2017
# 21                                      "LED Only"
# 22                                        8/5/2017
# 23                                   "All Package"
# 24                                      10/10/2017

# %% [markdown]
# how to read files that contains timeseries data?
# <br>
# case 4 = baseline simulation results for UnivLab_Allison
# <br>
# case 5 = synthetic exporter applied with several measures for UnivLab_Allison

# %%
file_case4 = "Case4_Baseline_UnivLab_Allison.csv"
file_case5 = "Case5_UnivLab_Allison-10.csv"

# %%
df_case1 = pd.read_csv(file_case4)
df_case2 = pd.read_csv(file_case5, skiprows = 4)

# %% [markdown]
# what are column headers?

# %%
df_case1.columns
# Out:
# Index(['Electricity', 'Natural Gas', 'District Cooling', 'District Heating'], dtype='object')

# %%
df_case2.columns
# Out:
# Index(['Timestamp', 'Building_Id_1_Electricity_[J]',
#        'Building_Id_1_NaturalGas_[J]', 'Scenario'],
#       dtype='object')

# %% [markdown]
# how to combine all files into one data frame?

# %%
df_combined_elec = pd.DataFrame()
df_combined_ng = pd.DataFrame()

# %%
df_combined_elec.insert(0, 'Timestamp', df_case2.Timestamp)
df_combined_elec.insert(1, 'Baseline_elec', df_case1.Electricity)
df_combined_elec.insert(2, 'Stitched1_elec', df_case2["Building_Id_1_Electricity_[J]"])
df_combined_ng.insert(0, 'Timestamp', df_case2.Timestamp)
df_combined_ng.insert(1, 'Baseline_ng', df_case1["Natural Gas"])
df_combined_ng.insert(2, 'Stitched1_ng', df_case2["Building_Id_1_NaturalGas_[J]"])

# %%
df_combined_elec
# Out:
#              Timestamp  Baseline_elec  Stitched1_elec
# 0     01/01/2017 00:00   1.185362e+07    1.185362e+07
# 1     01/01/2017 01:00   1.259670e+07    1.259670e+07
# 2     01/01/2017 02:00   1.036606e+07    1.036606e+07
# 3     01/01/2017 03:00   1.260137e+07    1.260137e+07
# 4     01/01/2017 04:00   1.259876e+07    1.259876e+07
# 5     01/01/2017 05:00   1.228122e+07    1.228122e+07
# 6     01/01/2017 06:00   1.558187e+07    1.558187e+07
# 7     01/01/2017 07:00   2.264945e+07    2.264945e+07
# 8     01/01/2017 08:00   3.912880e+07    3.912880e+07
# 9     01/01/2017 09:00   3.943398e+07    3.943398e+07
# 10    01/01/2017 10:00   3.992457e+07    3.992457e+07
# 11    01/01/2017 11:00   4.033587e+07    4.033587e+07
# 12    01/01/2017 12:00   3.908023e+07    3.908023e+07
# 13    01/01/2017 13:00   4.046054e+07    4.046054e+07
# 14    01/01/2017 14:00   4.083430e+07    4.083430e+07
# 15    01/01/2017 15:00   4.107408e+07    4.107408e+07
# 16    01/01/2017 16:00   4.082441e+07    4.082441e+07
# 17    01/01/2017 17:00   2.885699e+07    2.885699e+07
# 18    01/01/2017 18:00   1.909247e+07    1.909247e+07
# 19    01/01/2017 19:00   2.041255e+07    2.041255e+07
# 20    01/01/2017 20:00   1.511579e+07    1.511579e+07
# 21    01/01/2017 21:00   1.832930e+07    1.832930e+07
# 22    01/01/2017 22:00   9.670274e+06    9.670274e+06
# 23    01/01/2017 23:00   1.210912e+07    1.210912e+07
# 24    01/02/2017 00:00   1.259222e+07    1.259222e+07
# 25    01/02/2017 01:00   1.036883e+07    1.036883e+07
# 26    01/02/2017 02:00   1.260516e+07    1.260516e+07
# 27    01/02/2017 03:00   1.260406e+07    1.260406e+07
# 28    01/02/2017 04:00   1.038124e+07    1.038124e+07
# 29    01/02/2017 05:00   1.449492e+07    1.449492e+07
# ...                ...            ...             ...
# 8730  12/30/2017 18:00   1.928243e+07    1.708747e+07
# 8731  12/30/2017 19:00   2.166428e+07    1.839525e+07
# 8732  12/30/2017 20:00   1.588911e+07    1.341843e+07
# 8733  12/30/2017 21:00   1.960240e+07    1.708021e+07
# 8734  12/30/2017 22:00   1.015648e+07    8.383383e+06
# 8735  12/30/2017 23:00   5.908924e+06    1.299465e+07
# 8736  12/31/2017 00:00   1.126167e+07    1.274122e+07
# 8737  12/31/2017 01:00   1.093822e+07    9.806547e+06
# 8738  12/31/2017 02:00   1.307133e+07    1.214508e+07
# 8739  12/31/2017 03:00   1.295836e+07    1.206525e+07
# 8740  12/31/2017 04:00   1.054962e+07    9.526732e+06
# 8741  12/31/2017 05:00   1.575898e+07    1.443070e+07
# 8742  12/31/2017 06:00   1.629743e+07    1.486351e+07
# 8743  12/31/2017 07:00   2.307852e+07    2.026997e+07
# 8744  12/31/2017 08:00   3.997087e+07    3.170173e+07
# 8745  12/31/2017 09:00   4.111822e+07    3.248153e+07
# 8746  12/31/2017 10:00   4.454402e+07    3.388739e+07
# 8747  12/31/2017 11:00   4.801882e+07    3.648723e+07
# 8748  12/31/2017 12:00   4.823288e+07    3.674248e+07
# 8749  12/31/2017 13:00   4.930164e+07    3.758525e+07
# 8750  12/31/2017 14:00   4.706599e+07    3.621903e+07
# 8751  12/31/2017 15:00   4.669357e+07    3.575743e+07
# 8752  12/31/2017 16:00   4.484689e+07    3.523584e+07
# 8753  12/31/2017 17:00   3.194482e+07    2.657191e+07
# 8754  12/31/2017 18:00   1.962756e+07    1.698365e+07
# 8755  12/31/2017 19:00   2.235485e+07    1.892781e+07
# 8756  12/31/2017 20:00   1.640524e+07    1.383782e+07
# 8757  12/31/2017 21:00   2.015050e+07    1.752918e+07
# 8758  12/31/2017 22:00   1.031974e+07    8.523375e+06
# 8759  12/31/2017 23:00   5.908924e+06    8.824883e+06
#
# [8760 rows x 3 columns]

# %% [markdown]
# how to set Timestamp column as index column?

# %%
df_combined_elec["Timestamp"] = pd.to_datetime(df_combined_elec["Timestamp"])
df_combined_ng["Timestamp"] = pd.to_datetime(df_combined_ng["Timestamp"])

# %%
df_combined_elec.index = df_combined_elec["Timestamp"]
del df_combined_elec["Timestamp"]

# %%
df_combined_ng.index = df_combined_ng["Timestamp"]
del df_combined_ng["Timestamp"]

# %% [markdown]
# how to ploy the entire simulation period?

# %%
df_combined_elec.plot(figsize=(15,5))
df_combined_ng.plot(figsize=(15,5))

# %% [markdown]
# how to plot certain time period? for "LED only" scenario.

# %%
df_filtered_elec = df_combined_elec['1/1/2017':'1/5/2017']
df_filtered_ng = df_combined_ng['1/1/2017':'1/5/2017']

# %%
df_filtered_elec.plot(figsize=(15,5))
df_filtered_ng.plot(figsize=(15,5))
